# %%
# Installing all the required libraries

import numpy as np                        # for matric decleration
import matplotlib.pyplot as plt           # for visualization purpose
import cv2                                # for image processing purpose
from scipy.signal import convolve2d       # for convolution purpose

# %%
# Reading image

image = cv2.imread(r"C:\Users\Manoj\Desktop\House.jfif")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap = 'gray')

# %%
# Detecting edge with laplacian operator of cv2


Lappy=cv2.Laplacian(gray,40, 100)

plt.imshow(Lappy, cmap = 'gray')

# %%
# Detecting contour with cv2 inbuilt findContour method

ret, binary = cv2.threshold(gray, 127,255, cv2.THRESH_BINARY_INV)
contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

image = cv2.drawContours(image, contours, -1, (0,255,0), 2)
plt.imshow(image)
